# %%
from  validation_data import ValidationDataset

# %%
validation_dataset = ValidationDataset(path=r"validation\validation_data.csv")

# %%
validation_dataset.data
# Out:
#                                 A Total War Saga: Troy  Among Us  \
# A Total War Saga: Troy                             1.0       0.0
# Among Us                                           0.0       1.0
# Baldur's Gate                                      0.5       0.0
# Baldur's Gate II                                   0.5       0.0
# Baldur's Gate III                                  0.5       0.0
# ...                                                ...       ...
# Total War: Warhammer III                           1.0       0.0
# Uncharted 2: Among Thieves                         0.0       0.0
# Uncharted 3: Drake's Deception                     0.0       0.0
# Uncharted 4: A Thief's End                         0.0       0.0
# Unturned                                           0.0       0.0
#
#                                 Baldur's Gate  Baldur's Gate II  \
# A Total War Saga: Troy                    0.5               0.5
# ...
